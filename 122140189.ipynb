# %%
import matplotlib.pyplot as plt
import numpy as np

#Mengambil data audio
data_audio = os.path.join(os.getcwd(), 'file_suara', 'artorias.wav')

# Create some sample data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create the plot
plt.plot(x, y)
plt.title('Simple Sine Wave')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.grid(True)
plt.show()
